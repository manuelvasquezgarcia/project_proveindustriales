# %%
import pandas as pd

# %%
rf=['Random Forest', 0.890461, 5.221957, 0.848812, 0.848812, 0.954200]
dt=['Decision Tree', 0.895596, 4.948426, 0.856731, 0.856731, 0.955558]
lgbm=['LightGBM_OPT', 0.969762, 1.044381, 0.969762, 0.969762, 0.969762]

# %%
listam=[rf, dt, lgbm]
df=pd.DataFrame(listam, columns=['Algorithm', 'F1-score', 'LogLoss', 'Accuracy', 'Recall', 'Precision'])
df
# Out:
#        Algorithm  F1-score   LogLoss  Accuracy    Recall  Precision
# 0  Random Forest  0.890461  5.221957  0.848812  0.848812   0.954200
# 1  Decision Tree  0.895596  4.948426  0.856731  0.856731   0.955558
# 2   LightGBM_OPT  0.969762  1.044381  0.969762  0.969762   0.969762

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Algorithm'], df['F1-score'])
plt.show()
plt.savefig('seleccionmodelounobarras.png')
# Out:
# <img src="data:image/png;base64,..." width="382">

# %%
knn=['KNN', 0.783304, 0.739845, 0.739845, 0.846829]
dt2=['Decisin Tree', 0.788940, 0.748549, 0.748549, 0.851051]
lgbm2=['LightGBM', 0.893110, 0.897485, 0.897485, 0.890889]

# %%
listam2=[knn, dt2, lgbm2]
df2=pd.DataFrame(listam2, columns=['Algorithm', 'F1-score', 'Accuracy', 'Recall', 'Precision'])
df2
# Out:
#       Algorithm  F1-score  Accuracy    Recall  Precision
# 0           KNN  0.783304  0.739845  0.739845   0.846829
# 1  Decisin Tree  0.788940  0.748549  0.748549   0.851051
# 2      LightGBM  0.893110  0.897485  0.897485   0.890889

# %%
plt.bar(df2['Algorithm'], df['F1-score'])
plt.show
plt.savefig('seleccionmodelodosbarras.png')
# Out:
# <img src="data:image/png;base64,..." width="459">
